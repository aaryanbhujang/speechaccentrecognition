# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
import librosa
import os
import soundfile as sf
import torch, torchaudio
import torchaudio.functional as f
import re
from scipy.signal import resample
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Loading Dataset

# %%
dir = '../audio'
audio_list = os.listdir(dir)

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## Extracting MFCC

# %%
target_sample_rate = 44100

def extract_features(audio_file, n_fft=128, hop_length=32, n_mfcc=13):
    y, sr = sf.read(audio_file)
    
    # Check if sample rate is the same
    if sr != target_sample_rate:
        y = resample(y, int(len(y) * target_sample_rate / sr))
        sr = target_sample_rate 
        
    # Extract first 10 seconds of audio
    samples_10_sec = target_sample_rate * 5   
    y_10_sec = y[:samples_10_sec]

    # Extract MFCC
    mfccs = librosa.feature.mfcc(y = y_10_sec, sr=sr, n_mfcc=n_mfcc)
    
    # Normalize MFCCs
    mfccs_normalized = (mfccs - np.mean(mfccs)) / np.std(mfccs)

    return mfccs

# %%
data = []
for audio in audio_list:
    audio_path = dir + "/" + audio

    feature = extract_features(audio_path)    
    label = re.sub(r'\d+', '', audio[:-4])

    data.append((feature, label))

# %% [markdown]
# ## Converting to DataFrame

# %%
seperated_data =[]
label_arr = []
for f,l in data:
    mfcc_dict = {f'MFCC_{i+1}': np.mean(f[i]) for i in range(f.shape[0])}
    label_arr.append(l)
    seperated_data.append(mfcc_dict)

# %%
df_new = pd.DataFrame(seperated_data)
df_new['label'] = label_arr
df_new.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 0 -313.387142  112.209912   9.208533  31.371297  17.599882   9.825517
# 1 -308.946874  122.272772  -9.384793  41.453954   9.842569  24.173727
# 2 -347.384938  136.188490  10.197611  32.253288  24.675880  10.336794
# 3 -298.006915  129.921361  10.475242  33.206293  13.492498   9.520922
# 4 -372.659700  130.403802   1.091368  29.089592 -16.425140  14.560142
#
#      MFCC_7    MFCC_8     MFCC_9    MFCC_10    MFCC_11    MFCC_12    MFCC_13  \
# 0 -6.818651  3.574703  -5.140834  -2.762990  -0.331369 -12.408153  -1.767146
# 1 -7.813031  7.134889  -3.787519  -7.712986  -6.162725  -6.996228  -5.789065
# 2  1.990867 -6.767265  -7.718542 -20.401889 -23.570137  -8.270935   0.063733
# 3  9.531328  0.382934 -13.356250  -0.532661  -1.095989  -0.374853 -10.247236
# 4  1.826287  9.118744   5.361862  -5.334779   4.315571  -3.210909  -1.155939
#
#        label
# 0  afrikaans
# 1  afrikaans
# 2  afrikaans
# 3  afrikaans
# 4  afrikaans

# %%
df_new.isnull().sum()
# Out:
# MFCC_1     0
# MFCC_2     0
# MFCC_3     0
# MFCC_4     0
# MFCC_5     0
# MFCC_6     0
# MFCC_7     0
# MFCC_8     0
# MFCC_9     0
# MFCC_10    0
# MFCC_11    0
# MFCC_12    0
# MFCC_13    0
# label      0
# dtype: int64

# %%
print(len(df_new))
df_cleaned = df_new.dropna()
print(len(df_cleaned))
# Out:
# 2138
# 2138

# %%
accent_counts = df_cleaned['label'].value_counts()
print(accent_counts)
# Out:
# label
# english     579
# spanish     162
# arabic      102
# mandarin     65
# french       63
#            ...
# xasonga       1
# yapese        1
# yakut         1
# yupik         1
# zulu          1
# Name: count, Length: 200, dtype: int64

# %% [markdown]
# ## Oversampling Dataset

# %%
largest_accent = accent_counts.idxmax()
max_count = accent_counts.max()

# Oversample smaller accent groups to match the size of the largest group but take the ones with more than 30 audio files
oversampled_data = []
for accent, count in accent_counts.items():
    if accent != largest_accent and count > 30:
        accent_data = df_cleaned[df_cleaned['label'] == accent]
        oversampled_accent = accent_data.sample(n=max_count, replace=True, random_state=42)
        oversampled_data.append(oversampled_accent)
    elif accent == largest_accent:
        oversampled_data.append(df_cleaned[df_cleaned['label'] == accent])


balanced_df = pd.concat(oversampled_data)

# %%
# handle undersampling kl native / non native
# native = df_cleaned[df_cleaned['label'] == 'native']
# oversampled_native = native.sample(n=1559, replace=True, random_state=42)
# smallest = df_cleaned[df_cleaned['label'] == 'non-native']

# df_balanced = pd.concat([oversampled_native[:len(smallest)], smallest]).reset_index(drop=True)
# df_balanced.head()

# %%
# handle undersampling kl bbrp accent doang
# biggest = df_cleaned[df_cleaned['label'] == 'english']

# spanish = df_cleaned[df_cleaned['label'] == 'spanish']
# oversampled_spanish = spanish.sample(n=579, replace=True, random_state=42)
# arabic = df_cleaned[df_cleaned['label'] == 'arabic']
# oversampled_arabic = arabic.sample(n=579, replace=True, random_state=42)

# df_balanced = pd.concat([biggest, oversampled_spanish, oversampled_arabic]).reset_index(drop=True)
# print(Counter(df_balanced['label']))
# df_balanced.head()

# %%
df_shuffled = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)
df_shuffled.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 0 -350.413909  146.012515  -0.561183  24.982460  14.984915  -7.896947
# 1 -360.446924   91.822579  -9.679640  18.493258  -5.919586   2.653825
# 2 -331.043490   77.847124 -25.110570  31.520116   1.523058  12.005564
# 3 -341.591980  125.310231  11.918212  46.767906   4.580645  25.288167
# 4 -342.092509  105.003981  -2.640308  33.541817  -2.037903  23.239642
#
#       MFCC_7     MFCC_8     MFCC_9   MFCC_10   MFCC_11    MFCC_12   MFCC_13  \
# 0   9.522377  -8.188583 -13.922448  1.312431 -6.423112  -8.267679 -6.228956
# 1 -10.575413  -3.105132 -10.620578 -4.991244 -8.781288  -5.150831 -9.400118
# 2 -13.224500  14.930355 -14.909000  5.434671 -2.862760   3.824669 -3.374734
# 3  -3.849953   4.652052   0.635007 -2.047152 -2.329178  -9.701581 -4.347683
# 4  -5.145314  13.583640  -0.559146 -1.708056 -5.686018  13.113782 -1.983727
#
#         label
# 0      german
# 1      arabic
# 2      korean
# 3     turkish
# 4  portuguese

# %%
# Seperating Data to x and y
y = df_shuffled["label"]
x = df_shuffled.drop('label', axis = 1)

# %% [markdown]
# ## Encoding Label (From Categorial to Numerical)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y)

label_mapping = {label: encoded_label for label, encoded_label in zip(y, encoded_labels)}

# Print the mapping
class_label = []
print("Label mapping:")
for label, encoded_label in label_mapping.items():
    class_label.append(label)
    print(f"{label}: {encoded_label}")
# Out:
# Label mapping:
# german: 4
# arabic: 0
# korean: 6
# turkish: 12
# portuguese: 9
# russian: 10
# english: 2
# mandarin: 7
# dutch: 1
# spanish: 11
# polish: 8
# french: 3
# italian: 5

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Training with Machine Learning Model

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
knn_accuracy = knn.score(x_test, y_test)
knn_accuracy
# Out:
# 0.8917662682602921

# %%
y_train_pred_knn = knn.predict(x_train)
train_accuracy_knn = accuracy_score(y_train, y_train_pred_knn)
test_accuracy_knn = accuracy_score(y_test, knn_pred)

print("Training Accuracy: ", train_accuracy_knn)
print("Testing Accuracy: ", test_accuracy_knn)
# Out:
# Training Accuracy:  0.9277528649725959
# Testing Accuracy:  0.8917662682602921

# %%
accuracies = [train_accuracy_knn, test_accuracy_knn]

plt.figure(figsize=(8, 4))
plt.bar(['Training Accuracy', 'Testing Accuracy'], accuracies, color=['blue', 'green'])
plt.ylabel('Accuracy')
plt.title('Comparison of Training and Testing Accuracies in KNN Model')
plt.ylim([0, 1]) 
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state = 42)
dt.fit(x_train, y_train)
pred_dt = dt.predict(x_test)
dt_accuracy = dt.score(x_test, y_test)
dt_accuracy
# Out:
# 0.9548472775564409

# %%
y_train_pred_dt = dt.predict(x_train)
train_accuracy_dt = accuracy_score(y_train, y_train_pred_dt)
test_accuracy_dt = accuracy_score(y_test, pred_dt)

print("Training Accuracy: ", train_accuracy_dt)
print("Testing Accuracy: ", test_accuracy_dt)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9548472775564409

# %%
accuracies = [train_accuracy_dt, test_accuracy_dt]

plt.figure(figsize=(8, 4))
plt.bar(['Training Accuracy', 'Testing Accuracy'], accuracies, color=['blue', 'green'])
plt.ylabel('Accuracy')
plt.title('Comparison of Training and Testing Accuracies in Decision Tree Model')
plt.ylim([0, 1]) 
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
randf = RandomForestClassifier(random_state = 42)
randf.fit(x_train, y_train)
pred_randf = randf.predict(x_test)
randf_accuracy = randf.score(x_test, y_test)
randf_accuracy
# Out:
# 0.9867197875166003

# %%
y_train_pred_rf = randf.predict(x_train)
train_accuracy_rf = accuracy_score(y_train, y_train_pred_rf)
test_accuracy_rf = accuracy_score(y_test, pred_randf)

print("Training Accuracy: ", train_accuracy_rf)
print("Testing Accuracy: ", test_accuracy_rf)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9867197875166003

# %%
accuracies = [train_accuracy_rf, test_accuracy_rf]

plt.figure(figsize=(8, 4))
plt.bar(['Training Accuracy', 'Testing Accuracy'], accuracies, color=['blue', 'green'])
plt.ylabel('Accuracy')
plt.title('Comparison of Training and Testing Accuracies in Random Forest Model')
plt.ylim([0, 1]) 
plt.show()

# %%
import joblib as jb
# save models
jb.dump(knn, 'knn_model_5.joblib')
jb.dump(dt, 'dt_model_5.joblib')
jb.dump(randf, 'randf_model_5.joblib')
# Out:
# ['randf_model_5.joblib']

# %%
# # load models
# knn_default = jb.load('knn.joblib')
# dt_default = jb.load('dt.joblib')
# randf_default = jb.load('randf.joblib')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#       arabic       0.92      0.87      0.89       141
#        dutch       0.89      1.00      0.94       119
#      english       0.41      0.08      0.14       107
#       french       0.85      0.97      0.90       107
#       german       0.93      1.00      0.97       114
#      italian       0.93      1.00      0.96       119
#       korean       0.87      0.98      0.92       111
#     mandarin       0.90      0.94      0.92       124
#       polish       0.92      1.00      0.96       109
#   portuguese       0.89      1.00      0.94       110
#      russian       0.88      1.00      0.94       104
#      spanish       0.87      0.73      0.79       124
#      turkish       0.93      1.00      0.96       117
#
#     accuracy                           0.89      1506
#    macro avg       0.86      0.89      0.86      1506
# weighted avg       0.86      0.89      0.87      1506

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#       arabic       0.95      1.00      0.97       141
#        dutch       0.95      1.00      0.98       119
#      english       0.96      0.42      0.58       107
#       french       0.95      0.99      0.97       107
#       german       0.95      1.00      0.97       114
#      italian       0.94      1.00      0.97       119
#       korean       0.96      1.00      0.98       111
#     mandarin       0.99      1.00      1.00       124
#       polish       0.96      1.00      0.98       109
#   portuguese       0.97      1.00      0.99       110
#      russian       0.97      1.00      0.99       104
#      spanish       0.89      0.96      0.93       124
#      turkish       0.97      1.00      0.98       117
#
#     accuracy                           0.95      1506
#    macro avg       0.96      0.95      0.95      1506
# weighted avg       0.96      0.95      0.95      1506

# %%
print(classification_report(y_test, pred_randf))
# Out:
#               precision    recall  f1-score   support
#
#       arabic       0.99      1.00      1.00       141
#        dutch       0.99      1.00      1.00       119
#      english       0.95      0.87      0.91       107
#       french       1.00      0.99      1.00       107
#       german       0.99      1.00      1.00       114
#      italian       0.98      1.00      0.99       119
#       korean       1.00      1.00      1.00       111
#     mandarin       0.98      1.00      0.99       124
#       polish       0.99      1.00      1.00       109
#   portuguese       1.00      1.00      1.00       110
#      russian       0.99      1.00      1.00       104
#      spanish       0.96      0.96      0.96       124
#      turkish       1.00      1.00      1.00       117
#
#     accuracy                           0.99      1506
#    macro avg       0.99      0.99      0.99      1506
# weighted avg       0.99      0.99      0.99      1506

# %% [markdown]
# # CNN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %%
X = np.array(df_shuffled.drop('label', axis=1).values)  
y = df_shuffled['label'].values

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

y_onehot = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

# %%
# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D

def build_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(64, 3, activation='relu'))
    model.add(MaxPooling1D(2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(y_train.shape[1], activation='softmax'))

    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

input_shape = (X_train.shape[1], 1)  

model = build_cnn_model(input_shape)
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 189/189 - 3s - 15ms/step - accuracy: 0.1118 - loss: 3.0732 - val_accuracy: 0.1806 - val_loss: 2.4574
# Epoch 2/150
# 189/189 - 1s - 5ms/step - accuracy: 0.1455 - loss: 2.4834 - val_accuracy: 0.2045 - val_loss: 2.3919
# Epoch 3/150
# 189/189 - 1s - 4ms/step - accuracy: 0.1704 - loss: 2.4200 - val_accuracy: 0.2576 - val_loss: 2.2984
# Epoch 4/150
# 189/189 - 1s - 5ms/step - accuracy: 0.2008 - loss: 2.3362 - val_accuracy: 0.2656 - val_loss: 2.2264
# Epoch 5/150
# 189/189 - 1s - 5ms/step - accuracy: 0.2357 - loss: 2.2558 - val_accuracy: 0.3174 - val_loss: 2.1271
# Epoch 6/150
# 189/189 - 1s - 5ms/step - accuracy: 0.2752 - loss: 2.1523 - val_accuracy: 0.3672 - val_loss: 2.0187
# Epoch 7/150
# 189/189 - 1s - 5ms/step - accuracy: 0.3094 - loss: 2.0574 - val_accuracy: 0.3997 - val_loss: 1.8973
# Epoch 8/150
# 189/189 - 1s - 5ms/step - accuracy: 0.3380 - loss: 1.9708 - val_accuracy: 0.4489 - val_loss: 1.7670
# Epoch 9/150
# 189/189 - 1s - 5ms/step - accuracy: 0.3755 - loss: 1.8645 - val_accuracy: 0.4788 - val_loss: 1.6967
# Epoch 10/150
# 189/189 - 1s - 4ms/step - accuracy: 0.3935 - loss: 1.7914 - val_accuracy: 0.5053 - val_loss: 1.5912
# Epoch 11/150
# 189/189 - 1s - 4ms/step - accuracy: 0.4247 - loss: 1.7091 - val_accuracy: 0.5618 - val_loss: 1.4964
# Epoch 12/150
# 189/189 - 1s - 5ms/step - accuracy: 0.4413 - loss: 1.6616 - val_accuracy: 0.5830 - val_loss: 1.4169
# Epoch 13/150
# 189/189 - 1s - 5ms/step - accuracy: 0.4712 - loss: 1.5732 - val_accuracy: 0.5883 - val_loss: 1.3700
# Epoch 14/150
# 189/189 - 1s - 5ms/step - accuracy: 0.4855 - loss: 1.5162 - val_accuracy: 0.6096 - val_loss: 1.2915
# Epoch 15/150
# 189/189 - 1s - 5ms/step - accuracy: 0.5052 - loss: 1.4656 - val_accuracy: 0.6414 - val_loss: 1.2144
# Epoch 16/150
# 189/189 - 1s - 4ms/step - accuracy: 0.5147 - loss: 1.4536 - val_accuracy: 0.6262 - val_loss: 1.1954
# Epoch 17/150
# 189/189 - 1s - 4ms/step - accuracy: 0.5310 - loss: 1.3876 - val_accuracy: 0.6647 - val_loss: 1.1081
# Epoch 18/150
# 189/189 - 1s - 4ms/step - accuracy: 0.5539 - loss: 1.3151 - val_accuracy: 0.7151 - val_loss: 1.0094
# Epoch 19/150
# 189/189 - 1s - 5ms/step - accuracy: 0.5599 - loss: 1.2836 - val_accuracy: 0.7218 - val_loss: 1.0053
# Epoch 20/150
# 189/189 - 1s - 6ms/step - accuracy: 0.5645 - loss: 1.2773 - val_accuracy: 0.7244 - val_loss: 0.9491
# Epoch 21/150
# 189/189 - 1s - 4ms/step - accuracy: 0.5967 - loss: 1.1970 - val_accuracy: 0.7643 - val_loss: 0.8882
# Epoch 22/150
# 189/189 - 1s - 4ms/step - accuracy: 0.5931 - loss: 1.1680 - val_accuracy: 0.7829 - val_loss: 0.8363
# Epoch 23/150
# 189/189 - 1s - 5ms/step - accuracy: 0.6193 - loss: 1.1400 - val_accuracy: 0.7769 - val_loss: 0.7930
# Epoch 24/150
# 189/189 - 1s - 4ms/step - accuracy: 0.6263 - loss: 1.0918 - val_accuracy: 0.7278 - val_loss: 0.8771
# Epoch 25/150
# 189/189 - 1s - 4ms/step - accuracy: 0.6160 - loss: 1.1205 - val_accuracy: 0.7616 - val_loss: 0.8022
# Epoch 26/150
# 189/189 - 1s - 5ms/step - accuracy: 0.6399 - loss: 1.0535 - val_accuracy: 0.7975 - val_loss: 0.7239
# Epoch 27/150
# 189/189 - 1s - 5ms/step - accuracy: 0.6524 - loss: 1.0175 - val_accuracy: 0.8214 - val_loss: 0.6831
# Epoch 28/150
# 189/189 - 1s - 5ms/step - accuracy: 0.6550 - loss: 0.9995 - val_accuracy: 0.8201 - val_loss: 0.6702
# Epoch 29/150
# 189/189 - 1s - 4ms/step - accuracy: 0.6590 - loss: 0.9818 - val_accuracy: 0.8234 - val_loss: 0.6404
# Epoch 30/150
# 189/189 - 1s - 5ms/step - accuracy: 0.6652 - loss: 0.9699 - val_accuracy: 0.8127 - val_loss: 0.6351
# Epoch 31/150
# 189/189 - 1s - 4ms/step - accuracy: 0.6786 - loss: 0.9346 - val_accuracy: 0.8513 - val_loss: 0.5794
# Epoch 32/150
# 189/189 - 1s - 4ms/step - accuracy: 0.6809 - loss: 0.9097 - val_accuracy: 0.8619 - val_loss: 0.5549
# Epoch 33/150
# 189/189 - 1s - 3ms/step - accuracy: 0.6864 - loss: 0.9164 - val_accuracy: 0.8493 - val_loss: 0.5518
# Epoch 34/150
# 189/189 - 1s - 3ms/step - accuracy: 0.6962 - loss: 0.8867 - val_accuracy: 0.8400 - val_loss: 0.5605
# Epoch 35/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7017 - loss: 0.8546 - val_accuracy: 0.8745 - val_loss: 0.4917
# Epoch 36/150
# 189/189 - 1s - 4ms/step - accuracy: 0.7125 - loss: 0.8406 - val_accuracy: 0.8692 - val_loss: 0.4809
# Epoch 37/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7090 - loss: 0.8439 - val_accuracy: 0.8725 - val_loss: 0.4777
# Epoch 38/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7187 - loss: 0.8259 - val_accuracy: 0.8699 - val_loss: 0.4699
# Epoch 39/150
# 189/189 - 1s - 4ms/step - accuracy: 0.7238 - loss: 0.7943 - val_accuracy: 0.8792 - val_loss: 0.4775
# Epoch 40/150
# 189/189 - 1s - 5ms/step - accuracy: 0.7225 - loss: 0.8016 - val_accuracy: 0.8552 - val_loss: 0.4919
# Epoch 41/150
# 189/189 - 1s - 4ms/step - accuracy: 0.7324 - loss: 0.7642 - val_accuracy: 0.8606 - val_loss: 0.4551
# Epoch 42/150
# 189/189 - 1s - 4ms/step - accuracy: 0.7308 - loss: 0.7742 - val_accuracy: 0.8679 - val_loss: 0.4278
# Epoch 43/150
# 189/189 - 1s - 5ms/step - accuracy: 0.7314 - loss: 0.7898 - val_accuracy: 0.8891 - val_loss: 0.4122
# Epoch 44/150
# Epoch 65/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7889 - loss: 0.5997 - val_accuracy: 0.9183 - val_loss: 0.2974
# Epoch 66/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7894 - loss: 0.5929 - val_accuracy: 0.9203 - val_loss: 0.2988
# Epoch 67/150
# 189/189 - 1s - 4ms/step - accuracy: 0.7824 - loss: 0.6171 - val_accuracy: 0.9183 - val_loss: 0.2872
# Epoch 68/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7831 - loss: 0.6181 - val_accuracy: 0.9137 - val_loss: 0.2917
# Epoch 69/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7970 - loss: 0.6046 - val_accuracy: 0.9316 - val_loss: 0.2629
# Epoch 70/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7922 - loss: 0.5959 - val_accuracy: 0.9190 - val_loss: 0.2746
# Epoch 71/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7982 - loss: 0.5595 - val_accuracy: 0.9223 - val_loss: 0.2496
# Epoch 72/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7904 - loss: 0.6000 - val_accuracy: 0.9283 - val_loss: 0.2592
# Epoch 73/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8075 - loss: 0.5511 - val_accuracy: 0.9270 - val_loss: 0.2442
# Epoch 74/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8077 - loss: 0.5615 - val_accuracy: 0.9303 - val_loss: 0.2597
# Epoch 75/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8030 - loss: 0.5689 - val_accuracy: 0.9183 - val_loss: 0.2697
# Epoch 76/150
# 189/189 - 1s - 4ms/step - accuracy: 0.8085 - loss: 0.5642 - val_accuracy: 0.9236 - val_loss: 0.2556
# Epoch 77/150
# 189/189 - 1s - 3ms/step - accuracy: 0.7962 - loss: 0.5751 - val_accuracy: 0.9143 - val_loss: 0.2875
# Epoch 78/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8047 - loss: 0.5496 - val_accuracy: 0.9329 - val_loss: 0.2652
# Epoch 79/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8130 - loss: 0.5384 - val_accuracy: 0.9203 - val_loss: 0.2876
# Epoch 80/150
# 189/189 - 1s - 4ms/step - accuracy: 0.8070 - loss: 0.5503 - val_accuracy: 0.9382 - val_loss: 0.2267
# Epoch 81/150
# 189/189 - 1s - 4ms/step - accuracy: 0.8186 - loss: 0.5287 - val_accuracy: 0.9303 - val_loss: 0.2387
# Epoch 82/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8151 - loss: 0.5236 - val_accuracy: 0.9270 - val_loss: 0.2376
# Epoch 83/150
# 189/189 - 1s - 4ms/step - accuracy: 0.8148 - loss: 0.5238 - val_accuracy: 0.9343 - val_loss: 0.2277
# Epoch 84/150
# 189/189 - 1s - 4ms/step - accuracy: 0.8156 - loss: 0.5353 - val_accuracy: 0.9290 - val_loss: 0.2471
# Epoch 85/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8567 - loss: 0.4049 - val_accuracy: 0.9495 - val_loss: 0.1782
# Epoch 148/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8548 - loss: 0.4155 - val_accuracy: 0.9296 - val_loss: 0.2255
# Epoch 149/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8510 - loss: 0.4341 - val_accuracy: 0.9482 - val_loss: 0.1664
# Epoch 150/150
# 189/189 - 1s - 3ms/step - accuracy: 0.8560 - loss: 0.4157 - val_accuracy: 0.9509 - val_loss: 0.1769

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9554 - loss: 0.1801
# Test Loss: 0.17685972154140472
# Test Accuracy: 0.950863242149353

# %% [markdown]
# ## Plotting Accuracy & Loss of CNN Before Hyperparameter Tuned

# %%
metrics = history.history

plt.figure(figsize=(10,8))
plt.plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))
plt.title("Accuracy CNN")
plt.ylim([0,100])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(history.epoch, np.array(metrics['loss']), np.array(metrics['val_loss']))
plt.title("Loss CNN")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
import numpy as np

y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_true = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report

class_names = [
    "Arabic", "Dutch", "English", "French", "German", 
    "Italian", "Korean", "Mandarin", "Polish", "Portuguese", 
    "Russian", "Spanish", "Turkish"
]

report = classification_report(y_true, y_pred, target_names=class_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.91      0.95      0.93       141
#        Dutch       1.00      0.98      0.99       119
#      English       0.85      0.63      0.72       107
#       French       0.99      0.97      0.98       107
#       German       1.00      1.00      1.00       114
#      Italian       0.98      1.00      0.99       119
#       Korean       0.93      1.00      0.97       111
#     Mandarin       0.96      1.00      0.98       124
#       Polish       1.00      1.00      1.00       109
#   Portuguese       0.97      1.00      0.99       110
#      Russian       0.99      0.95      0.97       104
#      Spanish       0.80      0.86      0.83       124
#      Turkish       0.98      1.00      0.99       117
#
#     accuracy                           0.95      1506
#    macro avg       0.95      0.95      0.95      1506
# weighted avg       0.95      0.95      0.95      1506

# %%
model.save('cnn.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

model = load_model('cnn.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.save('cnn_model.keras')  # TensorFlow will use the SavedModel format by default

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from kerastuner import HyperModel

class CNNHyperModel(HyperModel):
    def __init__(self, input_shape, num_classes):
        self.input_shape = input_shape
        self.num_classes = num_classes

    def build(self, hp):
        model = Sequential()
        model.add(Conv1D(
            filters=hp.Int('filters1', min_value=32, max_value=128, step=32),
            kernel_size=hp.Int('kernel_size1', min_value=2, max_value=5, step=1),
            activation='relu',
            padding='same',
            input_shape=self.input_shape
        ))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Conv1D(
            filters=hp.Int('filters2', min_value=64, max_value=256, step=32),
            kernel_size=hp.Int('kernel_size2', min_value=2, max_value=5, step=1),
            activation='relu',
            padding='same'
        ))
        model.add(MaxPooling1D(pool_size=2))
        model.add(Flatten())
        model.add(Dense(
            hp.Int('dense_units', min_value=64, max_value=256, step=64),
            activation='relu'
        ))
        model.add(Dropout(hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1)))
        model.add(Dense(self.num_classes, activation='softmax'))

        model.compile(
            optimizer=Adam(
                hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')
            ),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        return model
# Out:
# C:\Users\aarya\AppData\Local\Temp\ipykernel_29804\670177796.py:4: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import HyperModel

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopper = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    verbose=1,
    min_lr=1e-6 
)

# %%
from kerastuner.tuners import RandomSearch

input_shape = (X_train.shape[1], 1) 
num_classes = y_train.shape[1] 

hypermodel = CNNHyperModel(input_shape=input_shape, num_classes=num_classes)

tuner = RandomSearch(
    hypermodel,
    objective='val_accuracy',
    max_trials=20,
    executions_per_trial=2,
    directory='model_tuning',
    project_name='AccentClassification'
)

tuner.search(x=X_train, y=y_train, epochs=50, validation_data=(X_test, y_test), callbacks=[early_stopper, reduce_lr])
# Out:
# Trial 11 Complete [00h 00m 24s]
# val_accuracy: 0.07270916551351547
#
# Best val_accuracy So Far: 0.9780876636505127
# Total elapsed time: 00h 51m 11s
#
# Search: Running Trial #12
#
# Value             |Best Value So Far |Hyperparameter
# 96                |128               |filters1
# 5                 |4                 |kernel_size1
# 192               |128               |filters2
# 5                 |5                 |kernel_size2
# 64                |192               |dense_units
# 0.4               |0.2               |dropout_rate
# 0.0012417         |0.00062822        |learning_rate
#
# Epoch 1/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.0649 - loss: 4.5663 - val_accuracy: 0.0710 - val_loss: 2.5652 - learning_rate: 0.0012
# Epoch 2/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0773 - loss: 2.5651 - val_accuracy: 0.0730 - val_loss: 2.5657 - learning_rate: 0.0012
# Epoch 3/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0748 - loss: 2.5651 - val_accuracy: 0.0691 - val_loss: 2.5659 - learning_rate: 0.0012
# Epoch 4/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0772 - loss: 2.5648 - val_accuracy: 0.0691 - val_loss: 2.5663 - learning_rate: 0.0012
# Epoch 5/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.0722 - loss: 2.5648 - val_accuracy: 0.0691 - val_loss: 2.5665 - learning_rate: 0.0012
# Epoch 6/50
# 187/189 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0783 - loss: 2.5651
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0006208595586940646.
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.0783 - loss: 2.5651 - val_accuracy: 0.0691 - val_loss: 2.5666 - learning_rate: 0.0012
# Epoch 7/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0810 - loss: 2.5648 - val_accuracy: 0.0691 - val_loss: 2.5667 - learning_rate: 6.2086e-04
# Epoch 8/50
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.0768 - loss: 2.5646 - val_accuracy: 0.0691 - val_loss: 2.5668 - learning_rate: 6.2086e-04
# Epoch 9/50
# 147/189 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0776 - loss: 2.5646
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 17
#       6 hypermodel = CNNHyperModel(input_shape=input_shape, num_classes=num_classes)
#       8 tuner = RandomSearch(
#       9     hypermodel,
#      10     objective='val_accuracy',
#    (...)
#      14     project_name='AccentClassification'
#      15 )
# ---> 17 tuner.search(x=X_train, y=y_train, epochs=50, validation_data=(X_test, y_test), callbacks=[early_stopper, reduce_lr])
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
best_model = tuner.get_best_models(num_models=1)[0]
loss, accuracy = best_model.evaluate(X_test, y_test)
print("Best model accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# c:\Users\aarya\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9747 - loss: 0.1066
# Best model accuracy: 97.88%

# %%
# Creating CNN model with the optimized parameter from the start
def create_cnn_model(input_shape, num_classes):
    model = Sequential()
    
    model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Flatten())
    
    model.add(Dense(256, activation='relu'))
    
    model.add(Dropout(0.2))
    
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer=Adam(learning_rate=0.0011876), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

best_model = create_cnn_model(input_shape, num_classes)

# Train data again from the start
history = best_model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/150
# 189/189 - 3s - 16ms/step - accuracy: 0.1194 - loss: 3.3744 - val_accuracy: 0.1428 - val_loss: 2.4561
# Epoch 2/150
# 189/189 - 1s - 7ms/step - accuracy: 0.1689 - loss: 2.4367 - val_accuracy: 0.2205 - val_loss: 2.3360
# Epoch 3/150
# 189/189 - 1s - 7ms/step - accuracy: 0.2433 - loss: 2.2641 - val_accuracy: 0.3320 - val_loss: 2.0964
# Epoch 4/150
# 189/189 - 1s - 7ms/step - accuracy: 0.3576 - loss: 1.9636 - val_accuracy: 0.4655 - val_loss: 1.7243
# Epoch 5/150
# 189/189 - 1s - 8ms/step - accuracy: 0.4687 - loss: 1.6258 - val_accuracy: 0.5950 - val_loss: 1.3441
# Epoch 6/150
# 189/189 - 1s - 7ms/step - accuracy: 0.5967 - loss: 1.2600 - val_accuracy: 0.7158 - val_loss: 0.9967
# Epoch 7/150
# 189/189 - 1s - 7ms/step - accuracy: 0.7045 - loss: 0.9593 - val_accuracy: 0.7829 - val_loss: 0.7582
# Epoch 8/150
# 189/189 - 1s - 7ms/step - accuracy: 0.7730 - loss: 0.7283 - val_accuracy: 0.8466 - val_loss: 0.6007
# Epoch 9/150
# 189/189 - 1s - 7ms/step - accuracy: 0.8339 - loss: 0.5508 - val_accuracy: 0.8718 - val_loss: 0.4130
# Epoch 10/150
# 189/189 - 1s - 7ms/step - accuracy: 0.8668 - loss: 0.4366 - val_accuracy: 0.9203 - val_loss: 0.3135
# Epoch 11/150
# 189/189 - 1s - 7ms/step - accuracy: 0.8829 - loss: 0.3606 - val_accuracy: 0.9223 - val_loss: 0.2712
# Epoch 12/150
# 189/189 - 1s - 6ms/step - accuracy: 0.
# 189/189 - 1s - 7ms/step - accuracy: 0.9759 - loss: 0.0785 - val_accuracy: 0.9562 - val_loss: 0.1932
# Epoch 36/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9689 - loss: 0.1085 - val_accuracy: 0.9608 - val_loss: 0.1638
# Epoch 37/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9661 - loss: 0.1045 - val_accuracy: 0.9668 - val_loss: 0.1492
# Epoch 38/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9706 - loss: 0.0855 - val_accuracy: 0.9701 - val_loss: 0.1536
# Epoch 39/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9801 - loss: 0.0597 - val_accuracy: 0.9655 - val_loss: 0.1482
# Epoch 40/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9781 - loss: 0.0659 - val_accuracy: 0.9695 - val_loss: 0.1603
# Epoch 41/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9754 - loss: 0.0711 - val_accuracy: 0.9608 - val_loss: 0.1896
# Epoch 42/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9696 - loss: 0.0934 - val_accuracy: 0.9641 - val_loss: 0.1815
# Epoch 43/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9734 - loss: 0.0815 - val_accuracy: 0.9714 - val_loss: 0.1408
# Epoch 44/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9824 - loss: 0.0531 - val_accuracy: 0.9622 - val_loss: 0.1914
# Epoch 45/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9761 - loss: 0.0785 - val_accuracy: 0.9681 - val_loss: 0.1727
# Epoch 46/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9772 - loss: 0.0672 - val_accuracy: 0.9695 - val_loss: 0.1344
# Epoch 47/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9689 - loss: 0.0964 - val_accuracy: 0.9548 - val_loss: 0.2284
# Epoch 48/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9816 - loss: 0.0598 - val_accuracy: 0.9721 - val_loss: 0.1477
# Epoch 49/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9731 - loss: 0.0884 - val_accuracy: 0.9622 - val_loss: 0.1651
# Epoch 50/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9836 - loss: 0.0454 - val_accuracy: 0.9635 - val_loss: 0.1798
# Epoch 51/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9839 - loss: 0.0513 - val_accuracy: 0.9728 - val_loss: 0.1634
# Epoch 52/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9806 - loss: 0.0665 - val_accuracy: 0.9688 - val_loss: 0.1839
# Epoch 53/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9821 - loss: 0.0504 - val_accuracy: 0.9701 - val_loss: 0.1728
# Epoch 54/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9753 - loss: 0.0838 - val_accuracy: 0.9635 - val_loss: 0.1894
# Epoch 55/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9772 - loss: 0.0710 - val_accuracy: 0.9701 - val_loss: 0.1421
# Epoch 56/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9759 - loss: 0.0797 - val_accuracy: 0.9648 - val_loss: 0.1850
# Epoch 57/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9824 - loss: 0.0528 - val_accuracy: 0.9688 - val_loss: 0.1774
# Epoch 58/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9842 - loss: 0.0469 - val_accuracy: 0.9675 - val_loss: 0.1673
# Epoch 59/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9864 - loss: 0.0410 - val_accuracy: 0.9714 - val_loss: 0.1898
# Epoch 60/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9801 - loss: 0.0617 - val_accuracy: 0.9681 - val_loss: 0.1674
# Epoch 61/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9792 - loss: 0.0670 - val_accuracy: 0.9648 - val_loss: 0.1786
# Epoch 62/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9812 - loss: 0.0660 - val_accuracy: 0.9661 - val_loss: 0.1899
# Epoch 63/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9841 - loss: 0.0510 - val_accuracy: 0.9734 - val_loss: 0.1831
# Epoch 64/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9851 - loss: 0.0450 - val_accuracy: 0.9661 - val_loss: 0.2021
# Epoch 65/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9852 - loss: 0.0492 - val_accuracy: 0.9734 - val_loss: 0.1894
# Epoch 66/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9782 - loss: 0.0681 - val_accuracy: 0.9535 - val_loss: 0.2804
# Epoch 67/150
# 189/189 - 1s - 4ms/step - accuracy: 0.9846 - loss: 0.0481 - val_accuracy: 0.9655 - val_loss: 0.2323
# Epoch 68/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9887 - loss: 0.0359 - val_accuracy: 0.9701 - val_loss: 0.1702
# Epoch 69/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9827 - loss: 0.0527 - val_accuracy: 0.9628 - val_loss: 0.2076
# Epoch 70/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9824 - loss: 0.0605 - val_accuracy: 0.9648 - val_loss: 0.2146
# Epoch 71/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9784 - loss: 0.0630 - val_accuracy: 0.9635 - val_loss: 0.2123
# Epoch 72/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9796 - loss: 0.0727 - val_accuracy: 0.9608 - val_loss: 0.2124
# Epoch 73/150
# 189/189 - 1s - 8ms/step - accuracy: 0.9804 - loss: 0.0598 - val_accuracy: 0.9734 - val_loss: 0.1847
# Epoch 74/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9880 - loss: 0.0370 - val_accuracy: 0.9748 - val_loss: 0.1577
# Epoch 75/150
# 189/189 - 1s - 8ms/step - accuracy: 0.9880 - loss: 0.0406 - val_accuracy: 0.9681 - val_loss: 0.2247
# Epoch 76/150
# 189/189 - 2s - 8ms/step - accuracy: 0.9847 - loss: 0.0482 - val_accuracy: 0.9648 - val_loss: 0.2807
# Epoch 77/150
# 189/189 - 1s - 8ms/step - accuracy: 0.9862 - loss: 0.0431 - val_accuracy: 0.9754 - val_loss: 0.1699
# Epoch 78/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9914 - loss: 0.0272 - val_accuracy: 0.9728 - val_loss: 0.2016
# Epoch 79/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9807 - loss: 0.0682 - val_accuracy: 0.9648 - val_loss: 0.2526
# Epoch 80/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9842 - loss: 0.0532 - val_accuracy: 0.9655 - val_loss: 0.2538
# Epoch 81/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9847 - loss: 0.0524 - val_accuracy: 0.9688 - val_loss: 0.2187
# Epoch 82/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9822 - loss: 0.0567 - val_accuracy: 0.9754 - val_loss: 0.1929
# Epoch 83/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9875 - loss: 0.0410 - val_accuracy: 0.9695 - val_loss: 0.1827
# Epoch 84/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9864 - loss: 0.0475 - val_accuracy: 0.9714 - val_loss: 0.2239
# Epoch 85/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9875 - loss: 0.0357 - val_accuracy: 0.9661 - val_loss: 0.2277
# Epoch 86/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9817 - loss: 0.0635 - val_accuracy: 0.9774 - val_loss: 0.1895
# Epoch 87/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9766 - loss: 0.0801 - val_accuracy: 0.9748 - val_loss: 0.1954
# Epoch 88/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9889 - loss: 0.0436 - val_accuracy: 0.9695 - val_loss: 0.2628
# Epoch 89/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9836 - loss: 0.0528 - val_accuracy: 0.9681 - val_loss: 0.2383
# Epoch 90/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9857 - loss: 0.0476 - val_accuracy: 0.9728 - val_loss: 0.2422
# Epoch 91/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9887 - loss: 0.0417 - val_accuracy: 0.9708 - val_loss: 0.2082
# Epoch 92/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9894 - loss: 0.0298 - val_accuracy: 0.9761 - val_loss: 0.1675
# Epoch 93/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9904 - loss: 0.0346 - val_accuracy: 0.9728 - val_loss: 0.1844
# Epoch 94/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9875 - loss: 0.0433 - val_accuracy: 0.9701 - val_loss: 0.2472
# Epoch 95/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9885 - loss: 0.0332 - val_accuracy: 0.9741 - val_loss: 0.2001
# Epoch 96/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9829 - loss: 0.0664 - val_accuracy: 0.9628 - val_loss: 0.2982
# Epoch 97/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9761 - loss: 0.0839 - val_accuracy: 0.9622 - val_loss: 0.2636
# Epoch 98/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9794 - loss: 0.0755 - val_accuracy: 0.9655 - val_loss: 0.2623
# Epoch 99/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9879 - loss: 0.0382 - val_accuracy: 0.9721 - val_loss: 0.1944
# Epoch 100/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9849 - loss: 0.0530 - val_accuracy: 0.9714 - val_loss: 0.2337
# Epoch 101/150
# 189/189 - 1s - 5ms/step - accuracy: 0.9889 - loss: 0.0358 - val_accuracy: 0.9714 - val_loss: 0.2105
# Epoch 102/150
# 189/189 - 1s - 6ms/step - accuracy: 0.
150
# 189/189 - 1s - 6ms/step - accuracy: 0.9922 - loss: 0.0267 - val_accuracy: 0.9728 - val_loss: 0.2427
# Epoch 127/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9811 - loss: 0.0764 - val_accuracy: 0.9655 - val_loss: 0.3535
# Epoch 128/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9837 - loss: 0.0529 - val_accuracy: 0.9668 - val_loss: 0.2911
# Epoch 129/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9864 - loss: 0.0458 - val_accuracy: 0.9655 - val_loss: 0.3641
# Epoch 130/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9887 - loss: 0.0343 - val_accuracy: 0.9721 - val_loss: 0.3115
# Epoch 131/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9972 - loss: 0.0071 - val_accuracy: 0.9668 - val_loss: 0.3586
# Epoch 132/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9902 - loss: 0.0339 - val_accuracy: 0.9668 - val_loss: 0.2892
# Epoch 133/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9904 - loss: 0.0352 - val_accuracy: 0.9675 - val_loss: 0.3159
# Epoch 134/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9862 - loss: 0.0574 - val_accuracy: 0.9548 - val_loss: 0.3575
# Epoch 135/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9842 - loss: 0.0559 - val_accuracy: 0.9661 - val_loss: 0.3120
# Epoch 136/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9920 - loss: 0.0302 - val_accuracy: 0.9701 - val_loss: 0.3013
# Epoch 137/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9932 - loss: 0.0197 - val_accuracy: 0.9622 - val_loss: 0.3126
# Epoch 138/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9904 - loss: 0.0395 - val_accuracy: 0.9608 - val_loss: 0.3752
# Epoch 139/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9912 - loss: 0.0308 - val_accuracy: 0.9635 - val_loss: 0.3173
# Epoch 140/150
# 189/189 - 1s - 7ms/step - accuracy: 0.9937 - loss: 0.0238 - val_accuracy: 0.9648 - val_loss: 0.3257
# Epoch 141/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9854 - loss: 0.0570 - val_accuracy: 0.9641 - val_loss: 0.3659
# Epoch 142/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9880 - loss: 0.0445 - val_accuracy: 0.9695 - val_loss: 0.2978
# Epoch 143/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9902 - loss: 0.0421 - val_accuracy: 0.9668 - val_loss: 0.3266
# Epoch 144/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9899 - loss: 0.0375 - val_accuracy: 0.9675 - val_loss: 0.3583
# Epoch 145/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9884 - loss: 0.0368 - val_accuracy: 0.9741 - val_loss: 0.2792
# Epoch 146/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9882 - loss: 0.0449 - val_accuracy: 0.9681 - val_loss: 0.3372
# Epoch 147/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9874 - loss: 0.0441 - val_accuracy: 0.9648 - val_loss: 0.3563
# Epoch 148/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9929 - loss: 0.0256 - val_accuracy: 0.9675 - val_loss: 0.2927
# Epoch 149/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9877 - loss: 0.0466 - val_accuracy: 0.9648 - val_loss: 0.3821
# Epoch 150/150
# 189/189 - 1s - 6ms/step - accuracy: 0.9885 - loss: 0.0443 - val_accuracy: 0.9641 - val_loss: 0.3859

# %% [markdown]
# ## Plotting Accuracy & Loss CNN After Hyperparameter Tuned

# %%
metrics = history.history

plt.figure(figsize=(10,8))
plt.plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))
plt.title("Accuracy CNN Hyperparameter Tuned")
plt.ylim([0,100])
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(history.epoch, np.array(metrics['loss']), np.array(metrics['val_loss']))
plt.title("Loss CNN Hyperparameter Tuned")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(['loss', 'val_loss'])
plt.show()

# %%
import numpy as np

# Predict the probabilities for each class
y_pred_probs = best_model.predict(X_test)
# Convert probabilities to class labels
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import classification_report

class_names = [
    "Arabic", "Dutch", "English", "French", "German", 
    "Italian", "Korean", "Mandarin", "Polish", "Portuguese", 
    "Russian", "Spanish", "Turkish"
]

report = classification_report(y_true, y_pred, target_names=class_names)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.97      0.99      0.98       141
#        Dutch       0.98      1.00      0.99       119
#      English       0.92      0.57      0.71       107
#       French       0.96      0.99      0.98       107
#       German       0.98      1.00      0.99       114
#      Italian       0.98      1.00      0.99       119
#       Korean       0.95      1.00      0.97       111
#     Mandarin       0.93      1.00      0.96       124
#       Polish       0.98      1.00      0.99       109
#   Portuguese       0.97      1.00      0.99       110
#      Russian       0.98      1.00      0.99       104
#      Spanish       0.92      0.96      0.94       124
#      Turkish       0.98      1.00      0.99       117
#
#     accuracy                           0.96      1506
#    macro avg       0.96      0.96      0.96      1506
# weighted avg       0.96      0.96      0.96      1506

# %%
# Save the model
best_model.save('cnn_tunning.h5') 
loaded_model = load_model('cnn_tunning.h5') 
loss, accuracy = loaded_model.evaluate(X_test, y_test)
print("Loaded model accuracy:", accuracy)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9567 - loss: 0.5621
# Loaded model accuracy: 0.9641434550285339

# %%
best_model.save('cnn_tunning_keras.keras')

# %%
from tensorflow.keras.models import load_model

# Load the best model you saved earlier
model = load_model('cnn_tunning.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def preprocess_audio(file_path, target_sample_rate=44100, n_mfcc=13):
    # Load data
    y, sr = librosa.load(file_path, sr=target_sample_rate)
    
    # Extract MFCC
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    
    # Normalize MFCC
    mfcc = (mfcc - np.mean(mfcc)) / np.std(mfcc)
    mfcc = mfcc.T
    
    # Get 13 MFCC coefficients
    if mfcc.shape[0] > 13:
        mfcc = mfcc[:13, :]
    else:
        # Padd with zeros if coefficients are less than 13
        mfcc = np.pad(mfcc, ((0, 13 - mfcc.shape[0]), (0, 0)), mode='constant')
    mfcc = np.mean(mfcc, axis=1, keepdims=True)
    
    # Expand dimensions to match the input shape of the model (batch_size, time_steps, features)
    mfcc = np.expand_dims(mfcc, axis=0)
    
    return mfcc

# %%
file_path = '../audio/uzbek1.mp3'

# Preprocess the audio
audio_data = preprocess_audio(file_path)
print("Shape of preprocessed audio data:", audio_data.shape)
# Out:
# Shape of preprocessed audio data: (1, 13, 1)

# %%
predictions = model.predict(audio_data)

predicted_class = np.argmax(predictions, axis=1)

class_names = [
    "Arabic", "Dutch", "English", "French", "German", 
    "Italian", "Korean", "Mandarin", "Polish", "Portuguese", 
    "Russian", "Spanish", "Turkish"
]

print(f"The predicted class for the audio file is: {class_names[predicted_class[0]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# The predicted class for the audio file is: English

# %%
model.save('cnn_tunning.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
from joblib import load

def load_model(model_name):
    if model_name.endswith('.h5'):
        model = tf.keras.models.load_model(model_name)
    else:
        model = load(f'{model_name}.joblib')
    return model

load_model('cnn_tunning.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# <Sequential name=sequential_1, built=True>
